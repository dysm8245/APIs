# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
# help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
myRacerdata = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
myRacerdata
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
def getRacerInfo(data):
    newData=[]
    for racer in data:
        racerDict = {}
        racerName = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        racerDict[racerName] = {
            "firstName": racer["Driver"]["givenName"],
            "lastName": racer["Driver"]["familyName"],
            "position": racer["position"]
        }
        newData.append(racerDict)
    return newData
getRacerInfo(myRacerdata)
# Out:
# [{'Kimi Räikkönen': {'firstName': 'Kimi',
#    'lastName': 'Räikkönen',
#    'position': '1'}},
#  {'Felipe Massa': {'firstName': 'Felipe',
#    'lastName': 'Massa',
#    'position': '2'}},
#  {'Lewis Hamilton': {'firstName': 'Lewis',
#    'lastName': 'Hamilton',
#    'position': '3'}},
#  {'Robert Kubica': {'firstName': 'Robert',
#    'lastName': 'Kubica',
#    'position': '4'}},
#  {'Nick Heidfeld': {'firstName': 'Nick',
#    'lastName': 'Heidfeld',
#    'position': '5'}},
#  {'Heikki Kovalainen': {'firstName': 'Heikki',
#    'lastName': 'Kovalainen',
#    'position': '6'}},
#  {'Mark Webber': {'firstName': 'Mark', 'lastName': 'Webber', 'position': '7'}},
#  {'Fernando Alonso': {'firstName': 'Fernando',
#    'lastName': 'Alonso',
#    'position': '8'}},
#  {'Jarno Trulli': {'firstName': 'Jarno',
#    'lastName': 'Trulli',
#    'position': '9'}},
#  {'Nico Rosberg': {'firstName': 'Nico',
#    'lastName': 'Rosberg',
#    'position': '10'}},
# ...

# %%
def getDriverInfoByYearAndRound(year, r):
    ur = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return getRacerInfo(data)
getDriverInfoByYearAndRound(2019,4)
# Out:
# [{'Kimi Räikkönen': {'firstName': 'Kimi',
#    'lastName': 'Räikkönen',
#    'position': '1'}},
#  {'Felipe Massa': {'firstName': 'Felipe',
#    'lastName': 'Massa',
#    'position': '2'}},
#  {'Lewis Hamilton': {'firstName': 'Lewis',
#    'lastName': 'Hamilton',
#    'position': '3'}},
#  {'Robert Kubica': {'firstName': 'Robert',
#    'lastName': 'Kubica',
#    'position': '4'}},
#  {'Nick Heidfeld': {'firstName': 'Nick',
#    'lastName': 'Heidfeld',
#    'position': '5'}},
#  {'Heikki Kovalainen': {'firstName': 'Heikki',
#    'lastName': 'Kovalainen',
#    'position': '6'}},
#  {'Mark Webber': {'firstName': 'Mark', 'lastName': 'Webber', 'position': '7'}},
#  {'Fernando Alonso': {'firstName': 'Fernando',
#    'lastName': 'Alonso',
#    'position': '8'}},
#  {'Jarno Trulli': {'firstName': 'Jarno',
#    'lastName': 'Trulli',
#    'position': '9'}},
#  {'Nico Rosberg': {'firstName': 'Nico',
#    'lastName': 'Rosberg',
#    'position': '10'}},
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 20 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
# url = "https://pokeapi.co/api/v2/pokemon/1/"
# response = requests.get(url)
# response
# data = response.json()["results"][0][""]
# data
def get20Pokemon():
    pokemonList = []
    for i in range(1,21):
        pokemonDict = {}
        url = f"https://pokeapi.co/api/v2/pokemon/{i}/"
        response = requests.get(url)
        data = response.json()
        pokemonDict = {
            "name": data["name"],
            "ability": data["abilities"][0]["ability"]["name"],
            "base_experience": data["base_experience"],
            "spriteImgURL": data["sprites"]["front_shiny"],
            "attack_base_stat": data["stats"][1]["base_stat"],
            "hp_base_stat": data["stats"][0]["base_stat"],
            "defense_base_stat": data["stats"][2]["base_stat"],
        }
        pokemonList.append(pokemonDict)
    return pokemonList
get20Pokemon()
# Out:
# [{'name': 'bulbasaur',
#   'ability': 'overgrow',
#   'base_experience': 64,
#   'spriteImgURL': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png',
#   'attack_base_stat': 49,
#   'hp_base_stat': 45,
#   'defense_base_stat': 49},
#  {'name': 'ivysaur',
#   'ability': 'overgrow',
#   'base_experience': 142,
#   'spriteImgURL': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/2.png',
#   'attack_base_stat': 62,
#   'hp_base_stat': 60,
#   'defense_base_stat': 63},
#  {'name': 'venusaur',
#   'ability': 'overgrow',
#   'base_experience': 263,
#   'spriteImgURL': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/3.png',
#   'attack_base_stat': 82,
#   'hp_base_stat': 80,
#   'defense_base_stat': 83},
#  {'name': 'charmander',
#   'ability': 'blaze',
#   'base_experience': 62,
#   'spriteImgURL': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png',
# ...
